# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("2026_team_summaries.csv")
print(df)
df = df.drop('Country', axis=1)
# Out:
#                    Country  2026_Average_Age  2026_Unique_Clubs_Represented  \
# 0                   Brazil              28.8                             20
# 1                Argentina              28.7                             19
# 2                   France              26.6                             18
# 3                  England              26.7                             16
# 4                  Germany              27.6                             13
# 5                    Spain              26.2                             13
# 6              Netherlands              27.3                             19
# 7                  Uruguay              28.2                             22
# 8                   Sweden              27.0                             26
# 9                  Belgium              27.1                             18
# 10                  Mexico              27.5                             21
# 11             Switzerland              27.8                             24
# 12                Portugal              27.5                             17
# 13                 Croatia              27.9                             24
# 14                 Austria              28.2                             22
# 15                Colombia              29.6                             24
# 16                Paraguay              28.5                             22
# 17                   Japan              26.9                             23
# 18                 Morocco              26.1                             24
# 19                Scotland              28.7                             22
# 20                 Senegal              26.6                             22
# 21                  Turkey              27.2                             16
# 22               Australia              26.9                             22
# 23                   Ghana              26.4                             23
# 24                  Norway              26.3                             22
# 25                 Ecuador              25.6                             23
# 26                 Tunisia              26.2                             24
# 27            Saudi Arabia              28.0                              9
# 28                 Algeria              26.5                             24
# 29                    Iran              29.8                             14
# 30                   Egypt              28.7                             14
# 31            South Africa              26.3                             12
# 32                  Canada              26.5                             22
# 33             New Zealand              27.8                             19
# 34  Bosnia and Herzegovina              26.0                             24
# 35             Ivory Coast              25.3                             25
# 36                   Haiti              27.0                             25
# 37           United States              26.4                             24
# 38                   Qatar              28.9                              8
# 39                 Czechia              27.2                             11
# 40                  Panama              30.0                             23
# 41                    Iraq              26.4                             20
# 42              Uzbekistan              27.7                             16
# 43                 Curaçao              27.5                             22
# 44                  Jordan              28.1                             14
# 45       Republic of Korea              27.5                             22
# 46              Cape Verde              29.2                             26
# 47                DR Congo              28.5                             24
#
#     Historical_Matches_Played  Historical_Goals_Scored
# 0                         123                      251
# 1                          98                      168
# 2                          82                      155
# 3                          81                      124
# 4                          58                      123
# 5                          75                      122
# 6                          63                      112
# 7                          63                       92
# 8                          55                       87
# 9                          59                       85
# 10                         66                       73
# 11                         48                       65
# 12                         38                       64
# 13                         34                       49
# 14                         31                       46
# 15                         28                       40
# 16                         32                       33
# 17                         29                       33
# 18                         29                       30
# 19                         26                       26
# 20                         15                       24
# 21                         10                       20
# 22                         24                       20
# 23                         18                       20
# 24                         13                       17
# 25                         17                       16
# 26                         21                       16
# 27                         22                       15
# 28                         16                       14
# 29                         15                       14
# 30                         12                       13
# 31                         13                       13
# 32                         11                       11
# 33                          9                        8
# 34                          4                        5
# 35                          3                        4
# 36                          6                        4
# 37                          5                        4
# 38                          6                        3
# 39                          3                        2
# 40                          6                        2
# 41                          5                        2
# 42                          1                        1
# 43                          3                        1
# 44                          1                        1
# 45                          0                        0
# 46                          0                        0
# 47                          0                        0

# %%
X=df.iloc[:, :-1].values
print(X)
# Out:
# [['Brazil' 28.8 20 123]
#  ['Argentina' 28.7 19 98]
#  ['France' 26.6 18 82]
#  ['England' 26.7 16 81]
#  ['Germany' 27.6 13 58]
#  ['Spain' 26.2 13 75]
#  ['Netherlands' 27.3 19 63]
#  ['Uruguay' 28.2 22 63]
#  ['Sweden' 27.0 26 55]
#  ['Belgium' 27.1 18 59]
#  ['Mexico' 27.5 21 66]
#  ['Switzerland' 27.8 24 48]
#  ['Portugal' 27.5 17 38]
#  ['Croatia' 27.9 24 34]
#  ['Austria' 28.2 22 31]
#  ['Colombia' 29.6 24 28]
#  ['Paraguay' 28.5 22 32]
#  ['Japan' 26.9 23 29]
#  ['Morocco' 26.1 24 29]
#  ['Scotland' 28.7 22 26]
#  ['Senegal' 26.6 22 15]
#  ['Turkey' 27.2 16 10]
#  ['Australia' 26.9 22 24]
#  ['Ghana' 26.4 23 18]
#  ['Norway' 26.3 22 13]
#  ['Ecuador' 25.6 23 17]
#  ['Tunisia' 26.2 24 21]
#  ['Saudi Arabia' 28.0 9 22]
#  ['Algeria' 26.5 24 16]
#  ['Iran' 29.8 14 15]
#  ['Egypt' 28.7 14 12]
#  ['South Africa' 26.3 12 13]
#  ['Canada' 26.5 22 11]
#  ['New Zealand' 27.8 19 9]
#  ['Bosnia and Herzegovina' 26.0 24 4]
#  ['Ivory Coast' 25.3 25 3]
#  ['Haiti' 27.0 25 6]
#  ['United States' 26.4 24 5]
#  ['Qatar' 28.9 8 6]
#  ['Czechia' 27.2 11 3]
#  ['Panama' 30.0 23 6]
#  ['Iraq' 26.4 20 5]
#  ['Uzbekistan' 27.7 16 1]
#  ['Curaçao' 27.5 22 3]
#  ['Jordan' 28.1 14 1]
#  ['Republic of Korea' 27.5 22 0]
#  ['Cape Verde' 29.2 26 0]
#  ['DR Congo' 28.5 24 0]]

# %%
y=df.iloc[:, -1].values
print(y)
# Out:
# [251 168 155 124 123 122 112  92  87  85  73  65  64  49  46  40  33  33
#   30  26  24  20  20  20  17  16  16  15  14  14  13  13  11   8   5   4
#    4   4   3   2   2   2   1   1   1   0   0   0]

# %%
print(df.isnull().sum())
# Out:
# Country                          0
# 2026_Average_Age                 0
# 2026_Unique_Clubs_Represented    0
# Historical_Matches_Played        0
# Historical_Goals_Scored          0
# dtype: int64

# %%
df.fillna(df.mean().round(1), inplace=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_18828\1414148485.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean().round(1), inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Country                          0
# 2026_Average_Age                 0
# 2026_Unique_Clubs_Represented    0
# Historical_Matches_Played        0
# Historical_Goals_Scored          0
# dtype: int64

# %%
y=df.iloc[:, -1].values

# %%
df.duplicated()
print(df['2026_Average_Age'].describe())
scaler=MinMaxScaler()
df1=pd.DataFrame(scaler.fit_transform(df))
print(df1)
# Out:
# count    48.000000
# mean     27.445833
# std       1.120972
# min      25.300000
# 25%      26.500000
# 50%      27.400000
# 75%      28.200000
# max      30.000000
# Name: 2026_Average_Age, dtype: float64
#            0         1         2         3
# 0   0.744681  0.666667  1.000000  1.000000
# 1   0.723404  0.611111  0.796748  0.669323
# 2   0.276596  0.555556  0.666667  0.617530
# 3   0.297872  0.444444  0.658537  0.494024
# 4   0.489362  0.277778  0.471545  0.490040
# 5   0.191489  0.277778  0.609756  0.486056
# 6   0.425532  0.611111  0.512195  0.446215
# 7   0.617021  0.777778  0.512195  0.366534
# 8   0.361702  1.000000  0.447154  0.346614
# 9   0.382979  0.555556  0.479675  0.338645
# 10  0.468085  0.722222  0.536585  0.290837
# 11  0.531915  0.888889  0.390244  0.258964
# 12  0.468085  0.500000  0.308943  0.254980
# 13  0.553191  0.888889  0.276423  0.195219
# 14  0.617021  0.777778  0.252033  0.183267
# 15  0.914894  0.888889  0.227642  0.159363
# 16  0.680851  0.777778  0.260163  0.131474
# 17  0.340426  0.833333  0.235772  0.131474
# 18  0.170213  0.888889  0.235772  0.119522
# 19  0.723404  0.777778  0.211382  0.103586
# 20  0.276596  0.777778  0.121951  0.095618
# 21  0.404255  0.444444  0.081301  0.079681
# 22  0.340426  0.777778  0.195122  0.079681
# 23  0.234043  0.833333  0.146341  0.079681
# 24  0.212766  0.777778  0.105691  0.067729
# 25  0.063830  0.833333  0.138211  0.063745
# 26  0.191489  0.888889  0.170732  0.063745
# 27  0.574468  0.055556  0.178862  0.059761
# 28  0.255319  0.888889  0.130081  0.055777
# 29  0.957447  0.333333  0.121951  0.055777
# 30  0.723404  0.333333  0.097561  0.051793
# 31  0.212766  0.222222  0.105691  0.051793
# 32  0.255319  0.777778  0.089431  0.043825
# 33  0.531915  0.611111  0.073171  0.031873
# 34  0.148936  0.888889  0.032520  0.019920
# 35  0.000000  0.944444  0.024390  0.015936
# 36  0.361702  0.944444  0.048780  0.015936
# 37  0.234043  0.888889  0.040650  0.015936
# 38  0.765957  0.000000  0.048780  0.011952
# 39  0.404255  0.166667  0.024390  0.007968
# 40  1.000000  0.833333  0.048780  0.007968
# 41  0.234043  0.666667  0.040650  0.007968
# 42  0.510638  0.444444  0.008130  0.003984
# 43  0.468085  0.777778  0.024390  0.003984
# 44  0.595745  0.333333  0.008130  0.003984
# 45  0.468085  0.777778  0.000000  0.000000
# 46  0.829787  1.000000  0.000000  0.000000
# 47  0.680851  0.888889  0.000000  0.000000

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)
print(X_train)
print(len(X_train))
print(X_test)
print(len(X_test))
# Out:
# [['Netherlands' 27.3 19 63]
#  ['South Africa' 26.3 12 13]
#  ['Uruguay' 28.2 22 63]
#  ['Cape Verde' 29.2 26 0]
#  ['Colombia' 29.6 24 28]
#  ['Senegal' 26.6 22 15]
#  ['England' 26.7 16 81]
#  ['Jordan' 28.1 14 1]
#  ['Mexico' 27.5 21 66]
#  ['Croatia' 27.9 24 34]
#  ['Curaçao' 27.5 22 3]
#  ['France' 26.6 18 82]
#  ['Japan' 26.9 23 29]
#  ['Iraq' 26.4 20 5]
#  ['Morocco' 26.1 24 29]
#  ['Australia' 26.9 22 24]
#  ['Germany' 27.6 13 58]
#  ['Egypt' 28.7 14 12]
#  ['United States' 26.4 24 5]
#  ['Scotland' 28.7 22 26]
#  ['New Zealand' 27.8 19 9]
#  ['Canada' 26.5 22 11]
#  ['Norway' 26.3 22 13]
#  ['Algeria' 26.5 24 16]
#  ['Uzbekistan' 27.7 16 1]
#  ['Republic of Korea' 27.5 22 0]
#  ['Switzerland' 27.8 24 48]
#  ['Sweden' 27.0 26 55]
#  ['Bosnia and Herzegovina' 26.0 24 4]
#  ['DR Congo' 28.5 24 0]
#  ['Ecuador' 25.6 23 17]
#  ['Paraguay' 28.5 22 32]
#  ['Belgium' 27.1 18 59]
#  ['Tunisia' 26.2 24 21]
#  ['Qatar' 28.9 8 6]
#  ['Ghana' 26.4 23 18]
#  ['Portugal' 27.5 17 38]
#  ['Haiti' 27.0 25 6]]
# 38
# [['Iran' 29.8 14 15]
#  ['Panama' 30.0 23 6]
#  ['Spain' 26.2 13 75]
#  ['Argentina' 28.7 19 98]
#  ['Turkey' 27.2 16 10]
#  ['Brazil' 28.8 20 123]
#  ['Ivory Coast' 25.3 25 3]
#  ['Czechia' 27.2 11 3]
#  ['Saudi Arabia' 28.0 9 22]
#  ['Austria' 28.2 22 31]]
# 10
